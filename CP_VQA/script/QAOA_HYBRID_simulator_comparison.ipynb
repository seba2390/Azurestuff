# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
from time import time
from joblib import Parallel, delayed

from src.QAOA.Qiskit_QAOA import Qiskit_QAOA
#from src.QAOA.Qsim_CP_VQA import Qsim_QAOA
from src.QAOA.Qulacs_QAOA import Qulacs_QAOA
from src.QAOA.Spynoza_QAOA import Spynoza_QAOA
from src.QAOA.Pennylane_QAOA import Pennylane_QAOA

from src.Qubo import Qubo
from src.Chain import Chain
from src.Tools import (portfolio_metrics, 
                       min_cost_partition, 
                       get_qubo, 
                       qubo_limits, 
                       check_qubo)

# %%
def simulate(settings: dict):
    result = {'N':settings['N']}
    # Generating random problem instance 
    expected_returns, covariances = portfolio_metrics(n=settings['N'], seed=settings['seed'])
    # Retrieving C_min, C_max and corresponding states for original portfolio problem
    constrained_result, full_result, lmbda = min_cost_partition(nr_qubits=settings['N'],
                                                                k=settings['k'],
                                                                mu=expected_returns,
                                                                sigma=covariances,
                                                                alpha=settings['alpha'])

    # Generating QUBO corresponding to current problem instance
    Q, offset = get_qubo(mu=expected_returns,
                         sigma=covariances, 
                         alpha=settings['alpha'],
                         lmbda=lmbda+1, # Adding small constant purposely
                         k=settings['k'])
    qubo = Qubo(Q=Q, offset=offset) 
    qubo.subspace_c_min, qubo.subspace_c_max = constrained_result['c_min'], constrained_result['c_max']
    qubo.subspace_x_min, qubo.subspace_x_max = constrained_result['s_min'], constrained_result['s_max']
    qubo.full_space_c_min, qubo.full_space_c_max = full_result['c_min'], full_result['c_max']
    check_qubo(QUBO_matrix=Q, QUBO_offset=offset, expected_returns=expected_returns, covariances=covariances, alpha=settings['alpha'], k=settings['k'])
     
    
    """qsim = Qsim_QAOA(N_qubits=settings['N'],
                       cardinality=settings['k'],
                       layers=settings['L'],
                       qubo=qubo)"""
    
    qulacs = Qulacs_QAOA(N_qubits=settings['N'],
                       cardinality=settings['k'],
                       layers=settings['L'],
                       qubo=qubo)
     
    qiskit = Qiskit_QAOA(N_qubits=settings['N'],
                       cardinality=settings['k'],
                       layers=settings['L'],
                       qubo=qubo)
     
    spynoza = Spynoza_QAOA(N_qubits=settings['N'],
                       cardinality=settings['k'],
                       layers=settings['L'],
                       qubo=qubo)
    
    pennylane = Pennylane_QAOA(N_qubits=settings['N'],
                       cardinality=settings['k'],
                       layers=settings['L'],
                       qubo=qubo)
    
     # Generating initial guess for rotation angles
    np.random.seed(settings['seed'])
    theta_min, theta_max = -2*np.pi, 2*np.pi
    N_angles = settings['L'] * len(settings['topology'].get_NNN_indices()) if settings['w_nnn'] else settings['L'] * len(settings['topology'].get_NN_indices())
    CPVQA_theta_i = np.random.uniform(theta_min, theta_max, N_angles)
    
    qiskit_start_time = time()
    qiskit_sim = sc.optimize.minimize(fun=qiskit.get_cost, 
                              x0=CPVQA_theta_i,
                              method=settings['opt_method'],
                              options={'disp': False, 
                                       'maxiter': settings['max_iter']})
    qiskit_stop_time = time()
    if qiskit_sim['nfev'] > 0:
        time_pr_iter = (qiskit_stop_time-qiskit_start_time) / qiskit_sim['nfev']
        result['qiskit'] = time_pr_iter
    

    """qsim_start_time = time()
    qsim_sim = sc.optimize.minimize(fun=qsim.get_cost, 
                              x0=CPVQA_theta_i,
                              method=settings['opt_method'],
                              options={'disp': False, 
                                       'maxiter': settings['max_iter']})
    qsim_stop_time = time()
    if qsim_sim['nfev'] > 0:
        time_pr_iter = (qsim_stop_time-qsim_start_time) / qsim_sim['nfev']
        result['qsim'] = time_pr_iter"""
         
    
    qulacs_start_time = time()
    qulacs_sim = sc.optimize.minimize(fun=qulacs.get_cost, 
                              x0=CPVQA_theta_i,
                              method=settings['opt_method'],
                              options={'disp': False, 
                                       'maxiter': settings['max_iter']})
    qulacs_stop_time = time()
    if qulacs_sim['nfev'] > 0:
        time_pr_iter = (qulacs_stop_time-qulacs_start_time) / qulacs_sim['nfev']
        result['qulacs'] = time_pr_iter
        
    
    spynoza_start_time = time()
    spynoza_sim = sc.optimize.minimize(fun=spynoza.get_cost, 
                              x0=CPVQA_theta_i,
                              method=settings['opt_method'],
                              options={'disp': False, 
                                       'maxiter': settings['max_iter']})
    spynoza_stop_time = time()
    if spynoza_sim['nfev'] > 0:
        time_pr_iter = (spynoza_stop_time-spynoza_start_time) / spynoza_sim['nfev']
        result['spynoza'] = time_pr_iter
        
    
    pennylane_start_time = time()
    pennylane_sim = sc.optimize.minimize(fun=pennylane.get_cost, 
                              x0=CPVQA_theta_i,
                              method=settings['opt_method'],
                              options={'disp': False, 
                                       'maxiter': settings['max_iter']})
    pennylane_stop_time = time()
    if pennylane_sim['nfev'] > 0:
        time_pr_iter = (pennylane_stop_time-pennylane_start_time) / pennylane_sim['nfev']
        result['pennylane'] = time_pr_iter

    
    return  result

# %%
layer_dict = {2:1,  3:1,  4:1,
              5:1,  6:1,  7:2,
              8:2,  9:2,  10:3,
              11:3, 12:3, 13:4,
              14:4, 15:4, 16:5,
              17:6, 18:6, 19:6, 
              20:7, 21:7, 22:7}

max_iter = 10
alpha=0.5
N_seeds = 25
N_min, N_max = 4, 15
sim_settings = []
for seed in range(N_seeds):
    for N in range(N_min, N_max+1):
        topology = Chain(N_qubits=N)
        topology.set_initialization_strategy(strategy=np.array([0 if i%2 == 0 else 1 for i in range(N)]))
        setting = {'N'         :N,       'alpha'   :alpha,   'L'       :layer_dict[N], 
                   'seed'      :seed,    'topology':topology,'max_iter':max_iter,
                   'opt_method':'COBYLA','w_nnn'   :True,    'k'       :N//2}
        sim_settings.append(setting)

# %%
N_jobs=15
r = Parallel(n_jobs=N_jobs, verbose=51, backend='loky')(delayed(simulate)(setting) for setting in sim_settings)
# Out:
# [Parallel(n_jobs=15)]: Using backend LokyBackend with 15 concurrent workers.
# [Parallel(n_jobs=15)]: Done   1 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=15)]: Done   2 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=15)]: Done   3 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=15)]: Done   4 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=15)]: Done   5 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=15)]: Done   6 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=15)]: Done   7 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=15)]: Done   8 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=15)]: Done   9 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=15)]: Done  10 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=15)]: Done  11 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=15)]: Done  12 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=15)]: Done  13 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=15)]: Done  14 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=15)]: Done  15 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=15)]: Done  16 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=15)]: Done  17 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=15)]: Done  18 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=15)]: Done  19 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=15)]: Done  20 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=15)]: Done  21 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=15)]: Done  22 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=15)]: Done  23 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=15)]: Done  24 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=15)]: Done  25 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=15)]: Done  26 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=15)]: Done  27 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=15)]: Done  28 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=15)]: Done  29 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=15)]: Done  30 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=15)]: Done  31 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=15)]: Done  32 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=15)]: Done  33 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=15)]: Done  34 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=15)]: Done  35 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=15)]: Done  36 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=15)]: Done  37 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=15)]: Done  38 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=15)]: Done  39 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=15)]: Done  40 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=15)]: Done  41 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=15)]: Done  42 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=15)]: Done  43 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=15)]: Done  44 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=15)]: Done  45 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=15)]: Done  46 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=15)]: Done  47 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=15)]: Done  48 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=15)]: Done  49 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=15)]: Done  50 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=15)]: Done  51 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=15)]: Done  52 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=15)]: Done  53 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=15)]: Done  54 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=15)]: Done  55 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=15)]: Done  56 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=15)]: Done  57 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=15)]: Done  58 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=15)]: Done  59 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=15)]: Done  60 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=15)]: Done  61 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=15)]: Done  62 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=15)]: Done  63 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=15)]: Done  64 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=15)]: Done  65 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=15)]: Done  66 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=15)]: Done  67 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=15)]: Done  68 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=15)]: Done  69 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=15)]: Done  70 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=15)]: Done  71 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=15)]: Done  72 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=15)]: Done  73 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=15)]: Done  74 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=15)]: Done  75 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=15)]: Done  76 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=15)]: Done  77 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=15)]: Done  78 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=15)]: Done  79 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=15)]: Done  80 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=15)]: Done  81 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=15)]: Done  82 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=15)]: Done  83 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=15)]: Done  84 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=15)]: Done  85 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=15)]: Done  86 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=15)]: Done  87 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=15)]: Done  88 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=15)]: Done  89 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=15)]: Done  90 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=15)]: Done  91 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=15)]: Done  92 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=15)]: Done  93 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=15)]: Done  94 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=15)]: Done  95 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=15)]: Done  96 tasks      | elapsed:   33.1s
# [Parallel(n_jobs=15)]: Done  97 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=15)]: Done  98 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=15)]: Done  99 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=15)]: Done 100 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=15)]: Done 101 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=15)]: Done 102 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=15)]: Done 103 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=15)]: Done 104 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=15)]: Done 105 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=15)]: Done 106 tasks      | elapsed:   38.6s
# [Parallel(n_jobs=15)]: Done 107 tasks      | elapsed:   38.6s
# [Parallel(n_jobs=15)]: Done 108 tasks      | elapsed:   38.7s
# [Parallel(n_jobs=15)]: Done 109 tasks      | elapsed:   38.7s
# [Parallel(n_jobs=15)]: Done 110 tasks      | elapsed:   38.8s
# [Parallel(n_jobs=15)]: Done 111 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=15)]: Done 112 tasks      | elapsed:   39.1s
# [Parallel(n_jobs=15)]: Done 113 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=15)]: Done 114 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=15)]: Done 115 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=15)]: Done 116 tasks      | elapsed:   40.1s
# [Parallel(n_jobs=15)]: Done 117 tasks      | elapsed:   40.4s
# [Parallel(n_jobs=15)]: Done 118 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=15)]: Done 119 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=15)]: Done 120 tasks      | elapsed:   41.5s
# [Parallel(n_jobs=15)]: Done 121 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=15)]: Done 122 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=15)]: Done 123 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=15)]: Done 124 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=15)]: Done 125 tasks      | elapsed:   43.4s
# [Parallel(n_jobs=15)]: Done 126 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=15)]: Done 127 tasks      | elapsed:   44.0s
# [Parallel(n_jobs=15)]: Done 128 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=15)]: Done 129 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=15)]: Done 130 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=15)]: Done 131 tasks      | elapsed:   45.5s
# [Parallel(n_jobs=15)]: Done 132 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=15)]: Done 133 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=15)]: Done 134 tasks      | elapsed:   46.2s
# [Parallel(n_jobs=15)]: Done 135 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=15)]: Done 136 tasks      | elapsed:   46.9s
# [Parallel(n_jobs=15)]: Done 137 tasks      | elapsed:   47.0s
# [Parallel(n_jobs=15)]: Done 138 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=15)]: Done 139 tasks      | elapsed:   47.5s
# [Parallel(n_jobs=15)]: Done 140 tasks      | elapsed:   48.2s
# [Parallel(n_jobs=15)]: Done 141 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=15)]: Done 142 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=15)]: Done 143 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=15)]: Done 144 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=15)]: Done 145 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=15)]: Done 146 tasks      | elapsed:   50.6s
# [Parallel(n_jobs=15)]: Done 147 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=15)]: Done 148 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=15)]: Done 149 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=15)]: Done 150 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=15)]: Done 151 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=15)]: Done 152 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=15)]: Done 153 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=15)]: Done 154 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=15)]: Done 155 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=15)]: Done 156 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=15)]: Done 157 tasks      | elapsed:   54.2s
# [Parallel(n_jobs=15)]: Done 158 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=15)]: Done 159 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=15)]: Done 160 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=15)]: Done 161 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=15)]: Done 162 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=15)]: Done 163 tasks      | elapsed:   55.2s
# [Parallel(n_jobs=15)]: Done 164 tasks      | elapsed:   55.9s
# [Parallel(n_jobs=15)]: Done 165 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=15)]: Done 166 tasks      | elapsed:   58.2s
# [Parallel(n_jobs=15)]: Done 167 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=15)]: Done 168 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=15)]: Done 169 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=15)]: Done 170 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=15)]: Done 171 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=15)]: Done 172 tasks      | elapsed:   58.6s
# [Parallel(n_jobs=15)]: Done 173 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=15)]: Done 174 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=15)]: Done 175 tasks      | elapsed:   59.3s
# [Parallel(n_jobs=15)]: Done 176 tasks      | elapsed:   60.0s
# [Parallel(n_jobs=15)]: Done 177 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 178 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 179 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 180 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 181 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 182 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 183 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=15)]: Done 184 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 185 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 186 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 187 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 188 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 189 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 190 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 191 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 192 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 193 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 194 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 195 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 196 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 197 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 198 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 199 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 200 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=15)]: Done 201 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 202 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 203 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 204 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 205 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 206 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 207 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 208 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 209 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 210 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 211 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 212 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 213 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 214 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 215 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 216 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 217 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 218 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 219 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 220 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 221 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 222 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 223 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=15)]: Done 224 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 225 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 226 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 227 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 228 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 229 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 230 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 231 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 232 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 233 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 234 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 235 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 236 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 237 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=15)]: Done 238 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 239 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 240 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 241 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 242 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 243 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 244 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 245 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 246 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 247 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 248 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 249 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 250 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 251 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 252 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 253 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 254 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 255 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 256 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 257 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=15)]: Done 258 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 259 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 260 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 261 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 262 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 263 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 264 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 265 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 266 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 267 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 268 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 269 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 270 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 271 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=15)]: Done 277 out of 300 | elapsed:  1.6min remaining:    7.7s
# [Parallel(n_jobs=15)]: Done 283 out of 300 | elapsed:  1.6min remaining:    5.7s
# [Parallel(n_jobs=15)]: Done 289 out of 300 | elapsed:  1.6min remaining:    3.8s
# [Parallel(n_jobs=15)]: Done 295 out of 300 | elapsed:  1.7min remaining:    1.8s
# [Parallel(n_jobs=15)]: Done 300 out of 300 | elapsed:  1.8min finished

# %%
qiskit_res  = {N: [] for N in range(N_min,N_max+1)}
qulacs_res  = {N: [] for N in range(N_min,N_max+1)}
qsim_res    = {N: [] for N in range(N_min,N_max+1)}
spynoza_res = {N: [] for N in range(N_min,N_max+1)}
pennylane_res = {N: [] for N in range(N_min,N_max+1)}

for res in r: 
    if res['qiskit'] is not None:
        qiskit_res[res['N']].append(res['qiskit'])
    if res['qulacs'] is not None:
        qulacs_res[res['N']].append(res['qulacs'])
    """if res['qsim'] is not None:
        qsim_res[res['N']].append(res['qsim'])"""
    if res['spynoza'] is not None:
        spynoza_res[res['N']].append(res['spynoza'])
    if res['pennylane'] is not None:
        pennylane_res[res['N']].append(res['pennylane'])

# %%
qiskit_avgs = np.array([[np.mean(qiskit_res[key]), np.std(qiskit_res[key])] for key in qiskit_res.keys()])
#qsim_avgs = np.array([[np.mean(qsim_res[key]), np.std(qsim_res[key])] for key in qsim_res.keys()])
qulacs_avgs = np.array([[np.mean(qulacs_res[key]), np.std(qulacs_res[key])] for key in qulacs_res.keys()])
spynoza_avgs = np.array([[np.mean(spynoza_res[key]), np.std(spynoza_res[key])] for key in spynoza_res.keys()])
pennylane_avgs = np.array([[np.mean(pennylane_res[key]), np.std(pennylane_res[key])] for key in pennylane_res.keys()])

N_vals = [n for n in range(N_min, N_max+1)]

fig, ax = plt.subplots(1,1,figsize=(8,4))

ax.set_title('QAOA (CPU)')

ax.errorbar(N_vals, qiskit_avgs[:,0], yerr=qiskit_avgs[:,1], fmt='.-', capsize=2, label='Qiskit', color='tab:blue')
#ax.errorbar(N_vals, qsim_avgs[:,0], yerr=qsim_avgs[:,1], fmt='.-', capsize=2, label='Qsim', color='tab:red')
ax.errorbar(N_vals, spynoza_avgs[:,0], yerr=spynoza_avgs[:,1], fmt='.-', capsize=2, label='Spynoza', color='tab:red')
ax.errorbar(N_vals, qulacs_avgs[:,0], yerr=qulacs_avgs[:,1], fmt='.-', capsize=2, label='Qulacs', color='tab:green')
ax.errorbar(N_vals, pennylane_avgs[:,0], yerr=pennylane_avgs[:,1], fmt='.-', capsize=2, label='Pennylane', color='tab:purple')

ax.hlines(0, N_vals[0], N_vals[-1],ls='--',color='k', lw = 1)
ax.set_ylabel('time per iteration [s]')
ax.set_xlabel('# Qubits')
ax.set_xticks(N_vals)

ax.fill_between(np.linspace(4,6,100), -np.ones(100)*0.1, np.ones(100)*0.3, alpha=0.2, color='k')
ax.text(4.3,0.225,'1 layer')

ax.fill_between(np.linspace(7,9,100), -np.ones(100)*0.1, np.ones(100)*0.3, alpha=0.2, color='k')
ax.text(7.3,0.225,'2 layers')

ax.fill_between(np.linspace(10,12,100), -np.ones(100)*0.1, np.ones(100)*0.3, alpha=0.2, color='k')
ax.text(10.3,0.225,'3 layers')

ax.fill_between(np.linspace(13,15,100), -np.ones(100)*0.1, np.ones(100)*0.3, alpha=0.2, color='k')
ax.text(13.3,0.225,'4 layers')


################## miniplot ##################
# inset axes....
axins_x_left, axins_y_lower, axins_x_width, axins_height = 0.08, 0.49, 0.575, 0.3
axins = ax.inset_axes([axins_x_left, axins_y_lower, axins_x_width, axins_height])
axins.errorbar(N_vals, qiskit_avgs[:,0], yerr=qiskit_avgs[:,1], fmt='.-', capsize=2, label='Qiskit', color='tab:blue')
#axins.errorbar(N_vals, qsim_avgs[:,0], yerr=qsim_avgs[:,1], fmt='.-', capsize=2, label='Qsim', color='tab:red')
axins.errorbar(N_vals, spynoza_avgs[:,0], yerr=spynoza_avgs[:,1], fmt='.-', capsize=2, label='Spynoza', color='tab:red')
axins.errorbar(N_vals, qulacs_avgs[:,0], yerr=qulacs_avgs[:,1], fmt='.-', capsize=2, label='Qulacs', color='tab:green')
axins.errorbar(N_vals, pennylane_avgs[:,0], yerr=pennylane_avgs[:,1], fmt='.-', capsize=2, label='Pennylane', color='tab:purple')

axins.hlines(0, N_vals[0], N_vals[-1],ls='--',color='k', lw = 1)

axins.set_xticks([4,5,6,7,8,9,10,11,12])
#axins.set_yticks([])
# sub region of the original image
x1, x2, y1, y2 = 3.99, 12.01, -0.005, 0.05
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.tick_params(axis='both', which='major', labelsize=8)
ax.indicate_inset_zoom(axins, edgecolor="black")



ax.legend(loc='upper right')
#plt.savefig('simulator_comparison_3.png', dpi=400)
